# %% [markdown]
# <a href="https://colab.research.google.com/github/deepshikha-data/sales-data-analysis-project/blob/main/Sales_data_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Sales Data Analysis Project")
# Out:
# Sales Data Analysis Project

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
# Basic statistics

df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Check missing values

df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# Total rows and columns

df.shape
# Out:
# (244, 7)

# %%
# Show columns

df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Total bill distribution

sns.histplot(df['total_bill'], kde=True)
plt.title("Total Bill Distribution")
plt.show()

# %%
# Relationship between total bill and tip

sns.scatterplot(data=df, x="total_bill", y="tip")
plt.title("Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %%
# Average values

print("Average Total Bill:", df['total_bill'].mean())
print("Average Tip:", df['tip'].mean())
print("Average Size:", df['size'].mean())
# Out:
# Average Total Bill: 19.78594262295082
# Average Tip: 2.99827868852459
# Average Size: 2.569672131147541

# %%
# Sales analysis by day

day_sales = df.groupby('day')['total_bill'].sum()

day_sales.plot(kind='bar')
plt.title("Total Sales by Day")
plt.xlabel("Day")
plt.ylabel("Total Sales")
plt.show()
